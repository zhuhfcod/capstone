# %% [markdown]
# <a href="https://colab.research.google.com/github/zhuhfcod/capstone/blob/main/CNN_image_only_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN Model using image feature

# %% [markdown]
# In this part, we would like to use CNN to solve the image-only news classification task. This part will include data cleaning, data processing  and image enhancement for image data, fine-tuning for the CNN model, final evaluation of the model and some error analysis

# %% [markdown]
# ### import package

# %%
#importing Libraries
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import resnet50
import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import os
import shutil as shutil
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
np.random.seed(42)

from matplotlib import style
style.use('fivethirtyeight')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/capstone/dataset/train/image"
path2 = "/content/drive/MyDrive/capstone/dataset/test/image"

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/capstone/dataset/train/image'):
    for filename in filenames:
        os.path.join(dirname, filename)

# %%
IMG_HEIGHT = 60
IMG_WIDTH = 60
channels = 3

# %%
NUM_CATEGORIES = len(os.listdir(path))
NUM_CATEGORIES
# Out:
# 5

# %% [markdown]
# ### Data processing and data cleaning

# %%
classes = { 1:'Business',
            2:'Entertainment', 
            3:'Politics', 
            4:'Sport', 
            5:'Technology'}

# %%
folders = os.listdir(path)

train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])
    
# Sorting the dataset on the basis of number of images in each class
zipped_lists = zip(train_number, class_num)
sorted_pairs = sorted(zipped_lists)
tuples = zip(*sorted_pairs)
train_number, class_num = [ list(tuple) for tuple in  tuples]

# Plotting the number of images in each class
plt.figure(figsize=(10,5))  
plt.bar(class_num, train_number)
plt.xticks(class_num, rotation='vertical')
plt.show()

# %%
# Visualizing 25 random images from test data
import random
from matplotlib.image import imread

plt.figure(figsize=(25,25))

# %%
image_data = []
image_labels = []
path = "/content/drive/MyDrive/capstone/dataset/train/image"
path2 = "/content/drive/MyDrive/capstone/dataset/test/image"


for i in range(NUM_CATEGORIES):
    paths = path + '/' + str(i+1)
    images = os.listdir(paths)
    print(images)

    for img in images:
        try:
            image = cv2.imread(paths + '/' + img)
            image_fromarray = Image.fromarray(image, 'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            image_data.append(np.array(resize_image))
            image_labels.append(i)
        except:
            a = 1
            #print("Error in " + img)

# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)

print(image_data.shape, image_labels.shape)
# Out:
# ['1149.jpg', '1234.jpg', '1458.jpg', '1296.jpg', '1219.jpg', '1101.jpg', '1408.jpg', '1245.jpg', '1073.jpg', '1265.jpg', '1207.jpg', '1485.jpg', '1248.jpg', '1272.jpg', '1471.jpg', '1257.jpg', '1255.jpg', '1413.jpg', '1464.jpg', '1145.jpg', '1152.jpg', '1020.jpg', '1226.jpg', '1491.jpg', '1360.jpg', '1440.jpg', '1049.jpg', '1083.jpg', '1407.jpg', '1434.jpg', '1510.jpg', '1157.jpg', '1277.jpg', '1335.jpg', '1330.jpg', '1055.jpg', '1282.jpg', '1323.jpg', '1473.jpg',
# %%
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.2, random_state=42, shuffle=True)

X_train = X_train/255 
X_val = X_val/255

print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (1295, 60, 60, 3)
# X_valid.shape (324, 60, 60, 3)
# y_train.shape (1295,)
# y_valid.shape (324,)

# %%
image2_data = []
image2_labels = []
path2 = "/content/drive/MyDrive/capstone/dataset/test/image"

for i in range(NUM_CATEGORIES):
    paths2 = path2 + '/' + str(i+1)
    images2 = os.listdir(paths2)
    print(images2)

    for img in images2:
      try:
        image = cv2.imread(paths2 + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        image2_data.append(np.array(resize_image))
        image2_labels.append(i)
      except:
        a = 1
        #print("Error in " + img)
X_test = np.array(image2_data)
y_test = np.array(image2_labels)

X_test = X_test/255
# Out:
# ['1170.jpg', '1068.jpg', '1135.jpg', '1489.jpg', '1103.jpg', '1229.jpg', '1198.jpg', '1447.jpg', '1056.jpg', '1481.jpg', '1375.jpg', '1116.jpg', '1045.jpg', '1396.jpg', '1123.jpg', '1496.jpg', '1376.jpg', '1279.jpg', '1172.jpg', '1402.jpg', '1167.jpg', '1339.jpg', '1393.jpg', '1341.jpg', '1097.jpg', '1202.jpg', '1400.jpg', '1162.jpg', '1235.jpg', '1359.jpg', '1488.jpg', '1487.jpg', '1242.jpg', '1038.jpg', '1292.jpg', '1406.jpg', '1256.jpg', '1037.jpg', '1046.jpg', '1078.jpg', '1251.jpg', '1421.jpg', '1350.jpg', '1308.jpg', '1220.jpg', '1224.jpg', '1382.jpg', '1150.jpg', '1210.jpg', '1418.jpg', '1188.jpg', '1351.jpg', '1320.jpg', '1275.jpg', '1161.jpg', '1180.jpg', '1403.jpg', '1154.jpg', '1342.jpg', '1317.jpg', '1218.jpg', '1024.jpg', '1498.jpg', '1141.jpg', '1194.jpg', '1419.jpg', '1356.jpg', '1143.jpg', '1307.jpg', '1411.jpg', '1176.jpg', '1148.jpg', '1357.jpg', '1379.jpg', '1085.jpg', '1142.jpg', '1263.jpg', '1249.jpg', '1361.jpg', '1173.jpg', '1332.jpg', '1314.jpg', '1155.jpg', '1099.jpg', '1138.jpg', '1371.jpg', '1369.jpg', '1303.jpg', '1442.jpg', '1503.jpg', '1039.jpg']
# ['2360.jpg', '2273.jpg', '2094.jpg', '2340.jpg', '2369.jpg', '2213.jpg', '2007.jpg', '2219.jpg', '2344.jpg', '2337.jpg', '2244.jpg', '2170.jpg', '2352.jpg', '2153.jpg', '2144.jpg', '2039.jpg', '2229.jpg', '2079.jpg', '2326.jpg', '2097.jpg', '2145.jpg', '2317.jpg', '2363.jpg', '2114.jpg', '2271.jpg', '2140.jpg', '2341.jpg', '2370.jpg', '2275.jpg', '2205.jpg', '2367.jpg', '2249.jpg', '2323.jpg', '2141.jpg', '2164.jpg', '2325.jpg', '2106.jpg', '2123.j
# ['5307.jpg', '5342.jpg', '5308.jpg', '5183.jpg', '5156.jpg', '5268.jpg', '5016.jpg', '5111.jpg', '5029.jpg', '5091.jpg', '5294.jpg', '5140.jpg', '5088.jpg', '5219.jpg', '5327.jpg', '5162.jpg', '5032.jpg', '5139.jpg', '5363.jpg', '5158.jpg', '5093.jpg', '5053.jpg', '5159.jpg', '5027.jpg', '5263.jpg', '5071.jpg', '5067.jpg', '5061.jpg', '5346.jpg', '5050.jpg', '5049.jpg', '5059.jpg', '5073.jpg', '5143.jpg', '5225.jpg', '5002.jpg', '5226.jpg', '5018.jpg', '5381.jpg', '5101.jpg', '5165.jpg', '5379.jpg', '5152.jpg', '5246.jpg', '5237.jpg', '5077.jpg', '5033.jpg', '5038.jpg', '5012.jpg', '5085.jpg', '5241.jpg', '5375.jpg', '5060.jpg', '5126.jpg', '5178.jpg', '5260.jpg', '5227.jpg', '5005.jpg', '5186.jpg', '5082.jpg', '5328.jpg', '5360.jpg', '5133.jpg', '5344.jpg', '5074.jpg', '5388.jpg', '5031.jpg', '5098.jpg', '5006.jpg', '5181.jpg', '5043.jpg', '5310.jpg', '5125.jpg', '5297.jpg', '5329.jpg', '5302.jpg', '5189.jpg', '5201.jpg']

# %%
shuffle_indexes = np.arange(X_test.shape[0])
np.random.shuffle(shuffle_indexes)
X_test = X_test[shuffle_indexes]
y_test = y_test[shuffle_indexes]

# %%
from keras.utils.np_utils import *

# %%
y_train = keras.utils.to_categorical(y_train, NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)
y_test = keras.utils.to_categorical(y_test, NUM_CATEGORIES)

print(y_train.shape)
print(y_val.shape)
# Out:
# (1295, 5)
# (324, 5)

# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
model = keras.models.Sequential([    
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(IMG_HEIGHT,IMG_WIDTH,channels)),
    keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    keras.layers.Conv2D(filters=512, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(rate=0.5),
    
    keras.layers.Dense(5, activation='softmax')
])

# %%
lr = 0.0001
epochs = 50

opt = Adam(lr=lr, decay=lr / (epochs * 0.5))
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
aug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode="nearest")

history = model.fit(aug.flow(X_train, y_train, batch_size=32), epochs=epochs, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 41/41 [==============================] - 107s 3s/step - loss: 3.1320 - accuracy: 0.3081 - val_loss: 1.5926 - val_accuracy: 0.2500
# Epoch 2/50
# 41/41 [==============================] - 104s 3s/step - loss: 1.9887 - accuracy: 0.3822 - val_loss: 1.6057 - val_accuracy: 0.2623
# Epoch 3/50
# 41/41 [==============================] - 104s 3s/step - loss: 1.7416 - accuracy: 0.4332 - val_loss: 1.6904 - val_accuracy: 0.2654
# Epoch 4/50
# 41/41 [==============================] - 104s 3s/step - loss: 1.5922 - accuracy: 0.4734 - val_loss: 1.7105 - val_accuracy: 0.2654
# Epoch 5/50
# 41/41 [==============================] - 104s 3s/step - loss: 1.5158 - accuracy: 0.5236 - val_loss: 2.0380 - val_accuracy: 0.2654
# Epoch 6/50
# 41/41 [==============================] - 105s 3s/step - loss: 1.3934 - accuracy: 0.5498 - val_loss: 1.7869 - val_accuracy: 0.2654
# Epoch 7/50
# 41/41 [==============================] - 105s 3s/step - loss: 1.3480 - accuracy: 0.5861 - val_loss: 1.8396 - val_accuracy: 0.2654
# Epoch 8/50
# 41/41 [==============================] - 105s 3s/step - loss: 1.1654 - accuracy: 0.6124 - val_loss: 2.4353 - val_accuracy: 0.2654
# Epoch 9/50
# 41/41 [==============================] - 104s 3s/step - loss: 1.0921 - accuracy: 0.6355 - val_loss: 2.1057 - val_accuracy: 0.2654
# Epoch 10/50
# 41/41 [==============================] - 106s 3s/step - loss: 1.0709 - accuracy: 0.6417 - val_loss: 1.6537 - val_accuracy: 0.2870
# Epoch 11/50
# 41/41 [==============================] - 105s 3s/step - loss: 1.0825 - accuracy: 0.6525 - val_loss: 1.8195 - val_accuracy: 0.3179
# Epoch 12/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.9147 - accuracy: 0.6857 - val_loss: 2.0937 - val_accuracy: 0.3148
# Epoch 13/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.9446 - accuracy: 0.6664 - val_loss: 2.0869 - val_accuracy: 0.3117
# Epoch 14/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.8057 - accuracy: 0.7097 - val_loss: 1.9911 - val_accuracy: 0.3611
# Epoch 15/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.6612 - accuracy: 0.7683 - val_loss: 1.9753 - val_accuracy: 0.3673
# Epoch 16/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.7108 - accuracy: 0.7429 - val_loss: 2.0050 - val_accuracy: 0.3981
# Epoch 17/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.6108 - accuracy: 0.7961 - val_loss: 1.9694 - val_accuracy: 0.4259
# Epoch 18/50
# 41/41 [==============================] - 104s 3s/step - loss: 0.6658 - accuracy: 0.7676 - val_loss: 2.0199 - val_accuracy: 0.4537
# Epoch 19/50
# 41/41 [==============================] - 106s 3s/step - loss: 0.5636 - accuracy: 0.8124 - val_loss: 2.0707 - val_accuracy: 0.4784
# Epoch 20/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.5086 - accuracy: 0.8278 - val_loss: 2.0423 - val_accuracy: 0.4475
# Epoch 21/50
# 41/41 [==============================] - 106s 3s/step - loss: 0.4973 - accuracy: 0.8324 - val_loss: 2.1634 - val_accuracy: 0.4815
# Epoch 22/50
# 41/41 [==============================] - 105s 3s/step - loss: 0.4389 - accuracy: 0.8394 - val_loss: 2.3078 - val_accuracy: 0.4599
# Epoch 23/50
# 41/41 [==============================] - 106s 3s/step - loss: 0.4612 - accuracy: 0.8293 - val_loss: 2.2855 - val_accuracy: 0.4877
# Epoch 24/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.3728 - accuracy: 0.8695 - val_loss: 2.2921 - val_accuracy: 0.4907
# Epoch 25/50
# 41/41 [==============================] - 107s 3s/step - loss: 0.4240 - accuracy: 0.8448 - val_loss: 2.3109 - val_accuracy: 0.4660
# Epoch 26/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.3921 - accuracy: 0.8749 - val_loss: 2.4816 - val_accuracy: 0.4907
# Epoch 27/50
# 41/41 [==============================] - 109s 3s/step - loss: 0.3556 - accuracy: 0.8710 - val_loss: 2.4025 - val_accuracy: 0.4660
# Epoch 28/50
# 41/41 [==============================] - 106s 3s/step - loss: 0.3709 - accuracy: 0.8764 - val_loss: 2.4641 - val_accuracy: 0.5216
# Epoch 29/50
# 41/41 [==============================] - 109s 3s/step - loss: 0.3304 - accuracy: 0.9004 - val_loss: 2.5354 - val_accuracy: 0.4630
# Epoch 30/50
# 41/41 [==============================] - 107s 3s/step - loss: 0.3063 - accuracy: 0.8988 - val_loss: 2.5138 - val_accuracy: 0.4907
# Epoch 31/50
# 41/41 [==============================] - 106s 3s/step - loss: 0.2739 - accuracy: 0.8973 - val_loss: 2.6728 - val_accuracy: 0.4784
# Epoch 32/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.2858 - accuracy: 0.8996 - val_loss: 2.5661 - val_accuracy: 0.4691
# Epoch 33/50
# 41/41 [==============================] - 111s 3s/step - loss: 0.2925 - accuracy: 0.8981 - val_loss: 2.6741 - val_accuracy: 0.4599
# Epoch 34/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.2372 - accuracy: 0.9143 - val_loss: 2.6905 - val_accuracy: 0.4877
# Epoch 35/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.2265 - accuracy: 0.9197 - val_loss: 2.3577 - val_accuracy: 0.4938
# Epoch 36/50
# 41/41 [==============================] - 107s 3s/step - loss: 0.2045 - accuracy: 0.9282 - val_loss: 2.4795 - val_accuracy: 0.5000
# Epoch 37/50
# 41/41 [==============================] - 107s 3s/step - loss: 0.2345 - accuracy: 0.9151 - val_loss: 2.4564 - val_accuracy: 0.4938
# Epoch 38/50
# 41/41 [==============================] - 107s 3s/step - loss: 0.2245 - accuracy: 0.9236 - val_loss: 2.3190 - val_accuracy: 0.5123
# Epoch 39/50
# 41/41 [==============================] - 109s 3s/step - loss: 0.2226 - accuracy: 0.9189 - val_loss: 2.5063 - val_accuracy: 0.4877
# Epoch 40/50
# 41/41 [==============================] - 113s 3s/step - loss: 0.2207 - accuracy: 0.9274 - val_loss: 2.4995 - val_accuracy: 0.5185
# Epoch 41/50
# 41/41 [==============================] - 110s 3s/step - loss: 0.1807 - accuracy: 0.9390 - val_loss: 2.6455 - val_accuracy: 0.4753
# Epoch 42/50
# 41/41 [==============================] - 110s 3s/step - loss: 0.1816 - accuracy: 0.9413 - val_loss: 2.4964 - val_accuracy: 0.5031
# Epoch 43/50
# 41/41 [==============================] - 110s 3s/step - loss: 0.1506 - accuracy: 0.9429 - val_loss: 2.4662 - val_accuracy: 0.5123
# Epoch 44/50
# 41/41 [==============================] - 110s 3s/step - loss: 0.1663 - accuracy: 0.9444 - val_loss: 2.5236 - val_accuracy: 0.4938
# Epoch 45/50
# 41/41 [==============================] - 111s 3s/step - loss: 0.1799 - accuracy: 0.9413 - val_loss: 2.4705 - val_accuracy: 0.5216
# Epoch 46/50
# 41/41 [==============================] - 109s 3s/step - loss: 0.1668 - accuracy: 0.9483 - val_loss: 2.6305 - val_accuracy: 0.5093
# Epoch 47/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.1738 - accuracy: 0.9382 - val_loss: 2.8894 - val_accuracy: 0.5031
# Epoch 48/50
# 41/41 [==============================] - 108s 3s/step - loss: 0.1729 - accuracy: 0.9459 - val_loss: 2.7316 - val_accuracy: 0.5216
# Epoch 49/50
# 41/41 [==============================] - 109s 3s/step - loss: 0.1407 - accuracy: 0.9560 - val_loss: 2.7358 - val_accuracy: 0.5216
# Epoch 50/50
# 41/41 [==============================] - 109s 3s/step - loss: 0.1593 - accuracy: 0.9467 - val_loss: 2.6539 - val_accuracy: 0.5185

# %% [markdown]
# ### Result evaluation and error analysis

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
image2_data = []
image2_labels = []
path2 = "/content/drive/MyDrive/capstone/dataset/test/image"

for i in range(NUM_CATEGORIES):
    paths2 = path2 + '/' + str(i+1)
    images2 = os.listdir(paths2)
    print(images2)

    for img in images2:
      try:
        image = cv2.imread(paths2 + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        image2_data.append(np.array(resize_image))
        image2_labels.append(i)
      except:
        a = 1
        #print("Error in " + img)
X_test = np.array(image2_data)

# %%
pred = model.predict(X_test)
classes_x=np.argmax(pred,axis=1)
image_labels=np.argmax(y_test ,axis=1)

print('Test Data accuracy: ', accuracy_score(image_labels, classes_x)*100)
# Out:
# Test Data accuracy:  57.24815724815725

# %%
model.save('CNNnews.h5')

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(image_labels, classes_x)

# %%
import seaborn as sns
df_cm = pd.DataFrame(cf, index = classes,  columns = classes)
plt.figure(figsize = (10,10))
sns.heatmap(df_cm, annot=True)

# %%
plt.figure(figsize = (25, 25))

start_index = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = classes_x[start_index + i]
    actual = image2_labels[start_index + i]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Actual={} || Pred={}'.format(actual, prediction), color = col)
    plt.imshow(X_test[start_index + i])
plt.show()
